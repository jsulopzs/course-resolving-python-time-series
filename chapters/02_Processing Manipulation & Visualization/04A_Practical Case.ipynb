# %% [markdown]
# # Practical Case: Energy Price per Market

# %% [markdown]
# <style>
#     table.custom-table {
#         max-width: 1000px;
#         width: 100%;
#         margin: 0 auto; /* centers the table on the page */
#     }
#
#     table.custom-table td {
#         background-color: #fff;
#     }
#
#     table.custom-table th, table.custom-table td {
#         text-align: center;
#         vertical-align: middle;
#         padding: 5px;
#         width: 333px; /* distribute the total width equally among three columns */
#     }
#
#     table.custom-table img {
#         width: 100%;
#         display: block; /* removes any gap under the image */
#     }
# </style>
#
#
# <table class="custom-table">
#     <thead>
#         <tr>
#             <th>Output: Market Volatility</th>
#             <th>Output: Average Monthly Price</th>
#             <th>Input: Hourly Price per Market</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>
#                 <img src="src/04_output_2.png" alt="Solar Image 1">
#             </td>
#             <td>
#                 <img src="src/04_output_1.png" alt="Solar Image 2">
#             </td>
#             <td>
#                 <img src="src/04_input.png" alt="Solar Image 3">
#             </td>
#         </tr>
#     </tbody>
# </table>

# %% [markdown]
# ## Data

# %%
import pandas as pd #!
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv('data/omie-markets-price.csv', index_col=0, parse_dates=True)
df.index = pd.to_datetime(df.index, utc=True).tz_convert('Europe/Madrid')
df
# Out:
#                                  0      1      2      3     4      5      6  \
# datetime_utc
# 2023-06-04 00:00:00+02:00  85.0525  85.00  82.01  76.11   NaN    NaN    NaN
# 2023-06-04 01:00:00+02:00  79.2075  85.00  84.99  80.01   NaN    NaN    NaN
# ...                            ...    ...    ...    ...   ...    ...    ...
# 2023-11-05 22:00:00+01:00  48.0075  23.44  26.87  22.86  22.0  22.86  27.86
# 2023-11-05 23:00:00+01:00  40.0250  15.92  18.42  16.42  14.0  16.40  19.00
#
#                                7
# datetime_utc
# 2023-06-04 00:00:00+02:00    NaN
# 2023-06-04 01:00:00+02:00    NaN
# ...                          ...
# 2023-11-05 22:00:00+01:00  62.85
# 2023-11-05 23:00:00+01:00  31.92
#
# [3721 rows x 8 columns]

# %% [markdown]
# ## Resampling the Time
# - [Date offset `rule` list](https://pandas.pydata.org/docs/user_guide/timeseries.html#dateoffset-objects)
# - [Pandas plot `kind` list](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)

# %% [markdown]
# ### Data Processing

# %%
# Out:
#       datetime_utc variable    value
# 0          2023-06        0  85.0525
# 1          2023-06        0  79.2075
# ...            ...      ...      ...
# 29766      2023-11        7  62.8500
# 29767      2023-11        7  31.9200
#
# [29768 rows x 3 columns]

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ### Data Processing

# %%
# Out:
#                 datetime_utc variable       value
# 0  2023-06-30 00:00:00+02:00        0   97.638391
# 1  2023-07-31 00:00:00+02:00        0   85.093915
# ..                       ...      ...         ...
# 46 2023-10-31 00:00:00+01:00        7  101.695968
# 47 2023-11-30 00:00:00+01:00        7   16.108250
#
# [48 rows x 3 columns]

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ## Visualize Time Series Correlation

# %% [markdown]
# ### Scatter Matrix
#
# - [Plotly Express Overview](https://plotly.com/python/plotly-express/#overview)

# %%
# Out:
#                                    0          1          2          3  \
# datetime_utc
# 2023-06-04 00:00:00+02:00  80.365037  82.406726  82.143780  80.778155
# 2023-06-11 00:00:00+02:00  99.523296  94.653363  96.041637  96.536607
# ...                              ...        ...        ...        ...
# 2023-10-29 00:00:00+02:00  60.217877  22.966450  22.814024  22.912337
# 2023-11-05 00:00:00+01:00  37.020104   1.254583  -1.687083  -2.285417
#
#                                    4          5          6           7
# datetime_utc
# 2023-06-04 00:00:00+02:00  82.054357  83.314454  81.915952   98.137321
# 2023-06-11 00:00:00+02:00  95.343571  95.247185  94.569405  118.872679
# ...                              ...        ...        ...         ...
# 2023-10-29 00:00:00+02:00  21.837766  18.931134  21.626726   15.592143
# 2023-11-05 00:00:00+01:00   0.807750   1.382647   8.056250   51.011250
#
# [23 rows x 8 columns]

# %% [markdown]
# ### Correlation Matrix

# %%
# Out:
# <style type="text/css">
# #T_3238e_row0_col0, #T_3238e_row1_col1, #T_3238e_row2_col2, #T_3238e_row3_col3, #T_3238e_row4_col4, #T_3238e_row5_col5, #T_3238e_row6_col6, #T_3238e_row7_col7 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_3238e_row0_col1, #T_3238e_row1_col0 {
#   background-color: #3f4788;
#   color: #f1f1f1;
# }
# #T_3238e_row0_col2, #T_3238e_row2_col0 {
#   background-color: #424186;
#   color: #f1f1f1;
# }
# #T_3238e_row0_col3, #T_3238e_row3_col0 {
#   background-color: #463480;
#   color: #f1f1f1;
# }
# #T_3238e_row0_col4, #T_3238e_row4_col0 {
#   background-color: #46337f;
#   color: #f1f1f1;
# }
# #T_3238e_row0_col5, #T_3238e_row0_col7, #T_3238e_row5_col0, #T_3238e_row7_col0 {
#   background-color: #472d7b;
#   color: #f1f1f1;
# }
# #T_3238e_row0_col6, #T_3238e_row6_col0 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_3238e_row1_col2, #T_3238e_row2_col1 {
#   background-color: #ece51b;
#   color: #000000;
# }
# #T_3238e_row1_col3, #T_3238e_row3_col1 {
#   background-color: #cae11f;
#   color: #000000;
# }
# #T_3238e_row1_col4, #T_3238e_row3_col5, #T_3238e_row4_col1, #T_3238e_row5_col3 {
#   background-color: #c5e021;
#   color: #000000;
# }
# #T_3238e_row1_col5, #T_3238e_row4_col6, #T_3238e_row5_col1, #T_3238e_row6_col4 {
#   background-color: #b5de2b;
#   color: #000000;
# }
# #T_3238e_row1_col6, #T_3238e_row6_col1 {
#   background-color: #93d741;
#   color: #000000;
# }
# #T_3238e_row1_col7, #T_3238e_row7_col1 {
#   background-color: #44bf70;
#   color: #f1f1f1;
# }
# #T_3238e_row2_col3, #T_3238e_row3_col2 {
#   background-color: #dde318;
#   color: #000000;
# }
# #T_3238e_row2_col4, #T_3238e_row4_col2 {
#   background-color: #d0e11c;
#   color: #000000;
# }
# #T_3238e_row2_col5, #T_3238e_row5_col2 {
#   background-color: #bade28;
#   color: #000000;
# }
# #T_3238e_row2_col6, #T_3238e_row6_col2 {
#   background-color: #98d83e;
#   color: #000000;
# }
# #T_3238e_row2_col7, #T_3238e_row7_col2 {
#   background-color: #4cc26c;
#   color: #000000;
# }
# #T_3238e_row3_col4, #T_3238e_row4_col3, #T_3238e_row4_col5, #T_3238e_row5_col4 {
#   background-color: #dfe318;
#   color: #000000;
# }
# #T_3238e_row3_col6, #T_3238e_row6_col3 {
#   background-color: #a2da37;
#   color: #000000;
# }
# #T_3238e_row3_col7, #T_3238e_row7_col3 {
#   background-color: #52c569;
#   color: #000000;
# }
# #T_3238e_row4_col7, #T_3238e_row7_col4 {
#   background-color: #5cc863;
#   color: #000000;
# }
# #T_3238e_row5_col6, #T_3238e_row6_col5 {
#   background-color: #c0df25;
#   color: #000000;
# }
# #T_3238e_row5_col7, #T_3238e_row7_col5 {
#   background-color: #75d054;
#   color: #000000;
# }
# #T_3238e_row6_col7, #T_3238e_row7_col6 {
#   background-color: #8bd646;
#   color: #000000;
# }
# </style>
# <table id="T_3238e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3238e_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3238e_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_3238e_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_3238e_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_3238e_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_3238e_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_3238e_level0_col6" class="col_heading level0 col6" >6</th>
#       <th id="T_3238e_level0_col7" class="col_heading level0 col7" >7</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3238e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3238e_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_3238e_row0_col1" class="data row0 col1" >0.74</td>
#       <td id="T_3238e_row0_col2" class="data row0 col2" >0.74</td>
#       <td id="T_3238e_row0_col3" class="data row0 col3" >0.72</td>
#       <td id="T_3238e_row0_col4" class="data row0 col4" >0.72</td>
#       <td id="T_3238e_row0_col5" class="data row0 col5" >0.72</td>
#       <td id="T_3238e_row0_col6" class="data row0 col6" >0.68</td>
#       <td id="T_3238e_row0_col7" class="data row0 col7" >0.72</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3238e_row1_col0" class="data row1 col0" >0.74</td>
#       <td id="T_3238e_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_3238e_row1_col2" class="data row1 col2" >0.99</td>
#       <td id="T_3238e_row1_col3" class="data row1 col3" >0.97</td>
#       <td id="T_3238e_row1_col4" class="data row1 col4" >0.97</td>
#       <td id="T_3238e_row1_col5" class="data row1 col5" >0.96</td>
#       <td id="T_3238e_row1_col6" class="data row1 col6" >0.95</td>
#       <td id="T_3238e_row1_col7" class="data row1 col7" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3238e_row2_col0" class="data row2 col0" >0.74</td>
#       <td id="T_3238e_row2_col1" class="data row2 col1" >0.99</td>
#       <td id="T_3238e_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_3238e_row2_col3" class="data row2 col3" >0.98</td>
#       <td id="T_3238e_row2_col4" class="data row2 col4" >0.98</td>
#       <td id="T_3238e_row2_col5" class="data row2 col5" >0.97</td>
#       <td id="T_3238e_row2_col6" class="data row2 col6" >0.95</td>
#       <td id="T_3238e_row2_col7" class="data row2 col7" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3238e_row3_col0" class="data row3 col0" >0.72</td>
#       <td id="T_3238e_row3_col1" class="data row3 col1" >0.97</td>
#       <td id="T_3238e_row3_col2" class="data row3 col2" >0.98</td>
#       <td id="T_3238e_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_3238e_row3_col4" class="data row3 col4" >0.98</td>
#       <td id="T_3238e_row3_col5" class="data row3 col5" >0.97</td>
#       <td id="T_3238e_row3_col6" class="data row3 col6" >0.95</td>
#       <td id="T_3238e_row3_col7" class="data row3 col7" >0.91</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3238e_row4_col0" class="data row4 col0" >0.72</td>
#       <td id="T_3238e_row4_col1" class="data row4 col1" >0.97</td>
#       <td id="T_3238e_row4_col2" class="data row4 col2" >0.98</td>
#       <td id="T_3238e_row4_col3" class="data row4 col3" >0.98</td>
#       <td id="T_3238e_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_3238e_row4_col5" class="data row4 col5" >0.98</td>
#       <td id="T_3238e_row4_col6" class="data row4 col6" >0.96</td>
#       <td id="T_3238e_row4_col7" class="data row4 col7" >0.92</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3238e_row5_col0" class="data row5 col0" >0.72</td>
#       <td id="T_3238e_row5_col1" class="data row5 col1" >0.96</td>
#       <td id="T_3238e_row5_col2" class="data row5 col2" >0.97</td>
#       <td id="T_3238e_row5_col3" class="data row5 col3" >0.97</td>
#       <td id="T_3238e_row5_col4" class="data row5 col4" >0.98</td>
#       <td id="T_3238e_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_3238e_row5_col6" class="data row5 col6" >0.97</td>
#       <td id="T_3238e_row5_col7" class="data row5 col7" >0.93</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3238e_row6_col0" class="data row6 col0" >0.68</td>
#       <td id="T_3238e_row6_col1" class="data row6 col1" >0.95</td>
#       <td id="T_3238e_row6_col2" class="data row6 col2" >0.95</td>
#       <td id="T_3238e_row6_col3" class="data row6 col3" >0.95</td>
#       <td id="T_3238e_row6_col4" class="data row6 col4" >0.96</td>
#       <td id="T_3238e_row6_col5" class="data row6 col5" >0.97</td>
#       <td id="T_3238e_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_3238e_row6_col7" class="data row6 col7" >0.94</td>
#     </tr>
#     <tr>
#       <th id="T_3238e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3238e_row7_col0" class="data row7 col0" >0.72</td>
#       <td id="T_3238e_row7_col1" class="data row7 col1" >0.90</td>
#       <td id="T_3238e_row7_col2" class="data row7 col2" >0.91</td>
#       <td id="T_3238e_row7_

# %% [markdown]
# ### Other Plots

# %% [markdown]
# ## Pivot Tables

# %% [markdown]
# ### Transform object to DataFrame
#
# > Only if you don't have a DataFrame yet.

# %%
# Out:
#                                  0      1      2      3     4      5      6  \
# datetime_utc
# 2023-06-04 00:00:00+02:00  85.0525  85.00  82.01  76.11   NaN    NaN    NaN
# 2023-06-04 01:00:00+02:00  79.2075  85.00  84.99  80.01   NaN    NaN    NaN
# ...                            ...    ...    ...    ...   ...    ...    ...
# 2023-11-05 22:00:00+01:00  48.0075  23.44  26.87  22.86  22.0  22.86  27.86
# 2023-11-05 23:00:00+01:00  40.0250  15.92  18.42  16.42  14.0  16.40  19.00
#
#                                7
# datetime_utc
# 2023-06-04 00:00:00+02:00    NaN
# 2023-06-04 01:00:00+02:00    NaN
# ...                          ...
# 2023-11-05 22:00:00+01:00  62.85
# 2023-11-05 23:00:00+01:00  31.92
#
# [3721 rows x 8 columns]

# %% [markdown]
# ### Time series categories in one column

# %%
# Out:
#                           variable    value
# datetime_utc
# 2023-06-04 00:00:00+02:00        0  85.0525
# 2023-06-04 01:00:00+02:00        0  79.2075
# ...                            ...      ...
# 2023-11-05 22:00:00+01:00        7  62.8500
# 2023-11-05 23:00:00+01:00        7  31.9200
#
# [29768 rows x 2 columns]

# %% [markdown]
# ### Create columns with datetime information

# %%
# Out:
#                           variable    value  year  month  day  hour
# datetime_utc
# 2023-06-04 00:00:00+02:00        0  85.0525  2023      6    4     0
# 2023-06-04 01:00:00+02:00        0  79.2075  2023      6    4     1
# ...                            ...      ...   ...    ...  ...   ...
# 2023-11-05 22:00:00+01:00        7  62.8500  2023     11    5    22
# 2023-11-05 23:00:00+01:00        7  31.9200  2023     11    5    23
#
# [29768 rows x 6 columns]

# %% [markdown]
# ### Process `pivot_table`
#
# - Use this methodology.

# %%
# Out:
# year            2023                                                  \
# month             6           7           8           9           10
# variable
# 0          97.638391   85.093915   96.249477  100.194153   94.872963
# 1          94.684198   91.092339   96.168737  102.947403   88.750153
# 2          95.288773   91.248011   96.828347  103.669743   90.501087
# 3          95.914884   91.646989   98.557755  104.023069   89.499597
# 4          95.972120   89.686202   96.464218  103.008917   88.457729
# 5          96.029466   89.736157   96.628643  104.153500   89.622770
# 6          97.206281   90.754167   96.983562  100.628847   89.059140
# 7         116.997315  111.757944  120.812661  124.659750  101.695968
#
# year
# month            11
# variable
# 0         45.956219
# 1          3.329417
# 2          3.699625
# 3          3.565750
# 4          3.217400
# 5          3.138294
# 6          4.678417
# 7         16.108250

# %% [markdown]
# ### Style DataFrame

# %%
# Out:
# <style type="text/css">
# #T_ecce3_row0_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_ecce3_row0_col1 {
#   background-color: #2383ba;
#   color: #f1f1f1;
# }
# #T_ecce3_row0_col2, #T_ecce3_row4_col2, #T_ecce3_row5_col2 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_ecce3_row0_col3 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_ecce3_row0_col4 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_ecce3_row0_col5 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_ecce3_row1_col0 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_ecce3_row1_col1, #T_ecce3_row2_col1 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_ecce3_row1_col2, #T_ecce3_row3_col0, #T_ecce3_row4_col0, #T_ecce3_row5_col0 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_ecce3_row1_col3, #T_ecce3_row4_col3 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_ecce3_row1_col4 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_ecce3_row1_col5, #T_ecce3_row3_col5, #T_ecce3_row4_col5, #T_ecce3_row5_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ecce3_row2_col0 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_ecce3_row2_col2, #T_ecce3_row6_col2 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_ecce3_row2_col3 {
#   background-color: #04629a;
#   color: #f1f1f1;
# }
# #T_ecce3_row2_col4, #T_ecce3_row6_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_ecce3_row2_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_ecce3_row3_col1 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_ecce3_row3_col2 {
#   background-color: #0569a5;
#   color: #f1f1f1;
# }
# #T_ecce3_row3_col3, #T_ecce3_row5_col3 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_ecce3_row3_col4, #T_ecce3_row6_col4 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_ecce3_row4_col1, #T_ecce3_row5_col1, #T_ecce3_row5_col4 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_ecce3_row4_col4 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_ecce3_row6_col0 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_ecce3_row6_col3 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_ecce3_row6_col5 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ecce3_row7_col0 {
#   background-color: #034973;
#   color: #f1f1f1;
# }
# #T_ecce3_row7_col1 {
#   background-color: #045585;
#   color: #f1f1f1;
# }
# #T_ecce3_row7_col2 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_ecce3_row7_col3 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ecce3_row7_col4 {
#   background-color: #05659f;
#   color: #f1f1f1;
# }
# #T_ecce3_row7_col5 {
#   background-color: #efe9f3;
#   color: #000000;
# }
# </style>
# <table id="T_ecce3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_ecce3_level0_col0" class="col_heading level0 col0" colspan="6">2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >month</th>
#       <th id="T_ecce3_level1_col0" class="col_heading level1 col0" >6</th>
#       <th id="T_ecce3_level1_col1" class="col_heading level1 col1" >7</th>
#       <th id="T_ecce3_level1_col2" class="col_heading level1 col2" >8</th>
#       <th id="T_ecce3_level1_col3" class="col_heading level1 col3" >9</th>
#       <th id="T_ecce3_level1_col4" class="col_heading level1 col4" >10</th>
#       <th id="T_ecce3_level1_col5" class="col_heading level1 col5" >11</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecce3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ecce3_row0_col0" class="data row0 col0" >97.64</td>
#       <td id="T_ecce3_row0_col1" class="data row0 col1" >85.09</td>
#       <td id="T_ecce3_row0_col2" class="data row0 col2" >96.25</td>
#       <td id="T_ecce3_row0_col3" class="data row0 col3" >100.19</td>
#       <td id="T_ecce3_row0_col4" class="data row0 col4" >94.87</td>
#       <td id="T_ecce3_row0_col5" class="data row0 col5" >45.96</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ecce3_row1_col0" class="data row1 col0" >94.68</td>
#       <td id="T_ecce3_row1_col1" class="data row1 col1" >91.09</td>
#       <td id="T_ecce3_row1_col2" class="data row1 col2" >96.17</td>
#       <td id="T_ecce3_row1_col3" class="data row1 col3" >102.95</td>
#       <td id="T_ecce3_row1_col4" class="data row1 col4" >88.75</td>
#       <td id="T_ecce3_row1_col5" class="data row1 col5" >3.33</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ecce3_row2_col0" class="data row2 col0" >95.29</td>
#       <td id="T_ecce3_row2_col1" class="data row2 col1" >91.25</td>
#       <td id="T_ecce3_row2_col2" class="data row2 col2" >96.83</td>
#       <td id="T_ecce3_row2_col3" class="data row2 col3" >103.67</td>
#       <td id="T_ecce3_row2_col4" class="data row2 col4" >90.50</td>
#       <td id="T_ecce3_row2_col5" class="data row2 col5" >3.70</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ecce3_row3_col0" class="data row3 col0" >95.91</td>
#       <td id="T_ecce3_row3_col1" class="data row3 col1" >91.65</td>
#       <td id="T_ecce3_row3_col2" class="data row3 col2" >98.56</td>
#       <td id="T_ecce3_row3_col3" class="data row3 col3" >104.02</td>
#       <td id="T_ecce3_row3_col4" class="data row3 col4" >89.50</td>
#       <td id="T_ecce3_row3_col5" class="data row3 col5" >3.57</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ecce3_row4_col0" class="data row4 col0" >95.97</td>
#       <td id="T_ecce3_row4_col1" class="data row4 col1" >89.69</td>
#       <td id="T_ecce3_row4_col2" class="data row4 col2" >96.46</td>
#       <td id="T_ecce3_row4_col3" class="data row4 col3" >103.01</td>
#       <td id="T_ecce3_row4_col4" class="data row4 col4" >88.46</td>
#       <td id="T_ecce3_row4_col5" class="data row4 col5" >3.22</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ecce3_row5_col0" class="data row5 col0" >96.03</td>
#       <td id="T_ecce3_row5_col1" class="data row5 col1" >89.74</td>
#       <td id="T_ecce3_row5_col2" class="data row5 col2" >96.63</td>
#       <td id="T_ecce3_row5_col3" class="data row5 col3" >104.15</td>
#       <td id="T_ecce3_row5_col4" class="data row5 col4" >89.62</td>
#       <td id="T_ecce3_row5_col5" class="data row5 col5" >3.14</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ecce3_row6_col0" class="data row6 col0" >97.21</td>
#       <td id="T_ecce3_row6_col1" class="data row6 col1" >90.75</td>
#       <td id="T_ecce3_row6_col2" class="data row6 col2" >96.98</td>
#       <td id="T_ecce3_row6_col3" class="data row6 col3" >100.63</td>
#       <td id="T_ecce3_row6_col4" class="data row6 col4" >89.06</td>
#       <td id="T_ecce3_row6_col5" class="data row6 col5" >4.68</td>
#     </tr>
#     <tr>
#       <th id="T_ecce3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ecce3_row7_col0" class="data row7 col0" >117.00</td>
#       <td id="T_ecce3_row7_col1" class="data row7 col1" >111.76</td>
#       <td id="T_ecce3_row7_col2" class="data row7 col2" >120.81</td>
#       <td id="T_ecce3_row7_col3" class="data row7 col3" >124.66</td>
#       <td id="T_ecce3_row7_col4" class="data row7 col4" >101.70</td>
#       <td id="T_ecce3_row7_col5" class="data row7 col5" >16.11</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Extra: Market Volatility

# %%
# Out:
# year           2023
# month            6          7          8          9          10         11
# variable
# 0         27.270494  33.455864  30.278325  30.457654  35.201571  20.641194
# 1         22.331025  24.568902  30.359023  27.008729  45.096822   7.150113
# 2         22.414241  24.718660  30.195758  26.620725  44.384349   9.287365
# 3         23.426913  24.275967  28.808742  25.185376  42.625002   8.564772
# 4         23.275849  25.770265  30.409341  26.657696  43.516185   6.860209
# 5         24.843783  27.474886  31.969705  28.244358  43.841741   8.281503
# 6         24.435026  27.014207  31.930346  32.433309  44.899976   9.100613
# 7         20.945630  16.743026  24.141078  22.921666  47.259793  20.626748

# %%
# Out:
# <style type="text/css">
# #T_3983f_row0_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_3983f_row0_col1 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_3983f_row0_col2, #T_3983f_row1_col2 {
#   background-color: #4c99c5;
#   color: #f1f1f1;
# }
# #T_3983f_row0_col3, #T_3983f_row4_col2 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_3983f_row0_col4 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_3983f_row0_col5, #T_3983f_row7_col5 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_3983f_row1_col0, #T_3983f_row2_col0 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_3983f_row1_col1 {
#   background-color: #8cb3d5;
#   color: #000000;
# }
# #T_3983f_row1_col3, #T_3983f_row6_col1 {
#   background-color: #75a9cf;
#   color: #f1f1f1;
# }
# #T_3983f_row1_col4 {
#   background-color: #03466e;
#   color: #f1f1f1;
# }
# #T_3983f_row1_col5 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_3983f_row2_col1, #T_3983f_row5_col0 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_3983f_row2_col2 {
#   background-color: #4e9ac6;
#   color: #f1f1f1;
# }
# #T_3983f_row2_col3, #T_3983f_row4_col3 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_3983f_row2_col4 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_3983f_row2_col5 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_3983f_row3_col0, #T_3983f_row4_col0 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_3983f_row3_col1 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_3983f_row3_col2 {
#   background-color: #5ea0ca;
#   color: #f1f1f1;
# }
# #T_3983f_row3_col3 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_3983f_row3_col4 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_3983f_row3_col5 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_3983f_row4_col1 {
#   background-color: #81aed2;
#   color: #f1f1f1;
# }
# #T_3983f_row4_col4 {
#   background-color: #03517e;
#   color: #f1f1f1;
# }
# #T_3983f_row4_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_3983f_row5_col1 {
#   background-color: #6fa7ce;
#   color: #f1f1f1;
# }
# #T_3983f_row5_col2 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_3983f_row5_col3 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_3983f_row5_col4 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_3983f_row5_col5 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_3983f_row6_col0 {
#   background-color: #8eb3d5;
#   color: #000000;
# }
# #T_3983f_row6_col2 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_3983f_row6_col3 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# #T_3983f_row6_col4 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_3983f_row6_col5 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_3983f_row7_col0 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_3983f_row7_col1 {
#   background-color: #d2d2e7;
#   color: #000000;
# }
# #T_3983f_row7_col2 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_3983f_row7_col3 {
#   background-color: #9ebad9;
#   color: #000000;
# }
# #T_3983f_row7_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3983f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th id="T_3983f_level0_col0" class="col_heading level0 col0" colspan="6">2023</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >month</th>
#       <th id="T_3983f_level1_col0" class="col_heading level1 col0" >6</th>
#       <th id="T_3983f_level1_col1" class="col_heading level1 col1" >7</th>
#       <th id="T_3983f_level1_col2" class="col_heading level1 col2" >8</th>
#       <th id="T_3983f_level1_col3" class="col_heading level1 col3" >9</th>
#       <th id="T_3983f_level1_col4" class="col_heading level1 col4" >10</th>
#       <th id="T_3983f_level1_col5" class="col_heading level1 col5" >11</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3983f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3983f_row0_col0" class="data row0 col0" >27.27</td>
#       <td id="T_3983f_row0_col1" class="data row0 col1" >33.46</td>
#       <td id="T_3983f_row0_col2" class="data row0 col2" >30.28</td>
#       <td id="T_3983f_row0_col3" class="data row0 col3" >30.46</td>
#       <td id="T_3983f_row0_col4" class="data row0 col4" >35.20</td>
#       <td id="T_3983f_row0_col5" class="data row0 col5" >20.64</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3983f_row1_col0" class="data row1 col0" >22.33</td>
#       <td id="T_3983f_row1_col1" class="data row1 col1" >24.57</td>
#       <td id="T_3983f_row1_col2" class="data row1 col2" >30.36</td>
#       <td id="T_3983f_row1_col3" class="data row1 col3" >27.01</td>
#       <td id="T_3983f_row1_col4" class="data row1 col4" >45.10</td>
#       <td id="T_3983f_row1_col5" class="data row1 col5" >7.15</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3983f_row2_col0" class="data row2 col0" >22.41</td>
#       <td id="T_3983f_row2_col1" class="data row2 col1" >24.72</td>
#       <td id="T_3983f_row2_col2" class="data row2 col2" >30.20</td>
#       <td id="T_3983f_row2_col3" class="data row2 col3" >26.62</td>
#       <td id="T_3983f_row2_col4" class="data row2 col4" >44.38</td>
#       <td id="T_3983f_row2_col5" class="data row2 col5" >9.29</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3983f_row3_col0" class="data row3 col0" >23.43</td>
#       <td id="T_3983f_row3_col1" class="data row3 col1" >24.28</td>
#       <td id="T_3983f_row3_col2" class="data row3 col2" >28.81</td>
#       <td id="T_3983f_row3_col3" class="data row3 col3" >25.19</td>
#       <td id="T_3983f_row3_col4" class="data row3 col4" >42.63</td>
#       <td id="T_3983f_row3_col5" class="data row3 col5" >8.56</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3983f_row4_col0" class="data row4 col0" >23.28</td>
#       <td id="T_3983f_row4_col1" class="data row4 col1" >25.77</td>
#       <td id="T_3983f_row4_col2" class="data row4 col2" >30.41</td>
#       <td id="T_3983f_row4_col3" class="data row4 col3" >26.66</td>
#       <td id="T_3983f_row4_col4" class="data row4 col4" >43.52</td>
#       <td id="T_3983f_row4_col5" class="data row4 col5" >6.86</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3983f_row5_col0" class="data row5 col0" >24.84</td>
#       <td id="T_3983f_row5_col1" class="data row5 col1" >27.47</td>
#       <td id="T_3983f_row5_col2" class="data row5 col2" >31.97</td>
#       <td id="T_3983f_row5_col3" class="data row5 col3" >28.24</td>
#       <td id="T_3983f_row5_col4" class="data row5 col4" >43.84</td>
#       <td id="T_3983f_row5_col5" class="data row5 col5" >8.28</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3983f_row6_col0" class="data row6 col0" >24.44</td>
#       <td id="T_3983f_row6_col1" class="data row6 col1" >27.01</td>
#       <td id="T_3983f_row6_col2" class="data row6 col2" >31.93</td>
#       <td id="T_3983f_row6_col3" class="data row6 col3" >32.43</td>
#       <td id="T_3983f_row6_col4" class="data row6 col4" >44.90</td>
#       <td id="T_3983f_row6_col5" class="data row6 col5" >9.10</td>
#     </tr>
#     <tr>
#       <th id="T_3983f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3983f_row7_col0" class="data row7 col0" >20.95</td>
#       <td id="T_3983f_row7_col1" class="data row7 col1" >16.74</td>
#       <td id="T_3983f_row7_col2" class="data row7 col2" >24.14</td>
#       <td id="T_3983f_row7_col3" class="data row7 col3" >22.92</td>
#       <td id="T_3983f_row7_col4" class="data row7 col4" >47.26</td>
#       <td id="T_3983f_row7_
